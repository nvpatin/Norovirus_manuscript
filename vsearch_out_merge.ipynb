# %% [markdown]
# ## This script takes individual (sample-specific) taxon raw abundance files, with one column named 'Taxonomy' and one named with the sample identifier, and merges them into a spreadsheet that can be used for bar plots, diversity analyses, etc.
#
# ## You need all your individual .csv files in one directory, and no other .csv files in that directory for this to work.
#
# ## For the Norovirus manuscript this was run after 'vsearch_out_format_for_merge.ipynb'

# %%
import os as os
import pandas as pd
import numpy as np
import glob as glob
from functools import reduce

# %%
cd ~/Dropbox\ \(GaTech\)/Norovirus/vsearch/vsearch_out/timeseries
# Out:
# /Users/npatin3/Dropbox (GaTech)/Norovirus/vsearch/vsearch_out/timeseries

# %% [markdown]
# ### Make a dictionary with sample name and associated file

# %%
files = {}
for file in glob.glob("*.csv"):
    a, b = file.split('.')
    x, y, z = a.split('_')
    name = x + '_' + y
    files[name] = file
print(files)
# Out:
# {'15_9': '15_9_pdformat.csv', '37_7': '37_7_pdformat.csv', '36_12': '36_12_pdformat.csv', '36_1': '36_1_pdformat.csv', '37_1': '37_1_pdformat.csv', '15_8': '15_8_pdformat.csv', '15_3': '15_3_pdformat.csv', '36_9': '36_9_pdformat.csv', '37_8': '37_8_pdformat.csv', '37_10': '37_10_pdformat.csv', '15_1': '15_1_pdformat.csv', '15_6': '15_6_pdformat.csv', '15_7': '15_7_pdformat.csv', '37_11': '37_11_pdformat.csv', '37_9': '37_9_pdformat.csv', '37_4': '37_4_pdformat.csv', '36_5': '36_5_pdformat.csv', '36_11': '36_11_pdformat.csv', '36_4': '36_4_pdformat.csv'}

# %% [markdown]
# ### Use the dictionary to merge all files on the Taxonomy file with a fill outer merge (keeping all taxa)

# %%
reads = []
for key in files:
    df = pd.read_csv(files[key])
    reads.append(df)

reads_df = reduce(lambda x, y: pd.merge(x, y, on = 'Taxonomy', how='outer'), reads)

# %%
reads_df.head(10)
# Out:
#                                             Taxonomy   15_9  37_7   36_12  \
# 0                             AELO01000022.3647.5110    1.0   NaN     NaN
# 1                                    AY196663.1.1261    1.0   NaN     NaN
# 2                             Acidobacteria;Subgroup    1.0   NaN     NaN
# 3  Acidobacteria;Thermoanaerobaculia;Thermoanaero...    1.0   NaN     NaN
# 4  Actinobacteria;Actinomycetales;Actinomycetacea...    1.0   2.0    11.0
# 5  Actinobacteria;Actinomycetales;Actinomycetacea...    6.0   2.0    42.0
# 6  Actinobacteria;Actinomycetales;Actinomycetacea...    1.0   NaN     8.0
# 7  Actinobacteria;Bifidobacteriales;Bifidobacteri...  162.0   NaN  1712.0
# 8  Actinobacteria;Bifidobacteriales;Bifidobacteri...   11.0   NaN   104.0
# 9  Actinobacteria;Bifidobacteriales;Bifidobacteri...   23.0   NaN   108.0
#
#     36_1  37_1   15_8   15_3  36_9   37_8  37_10   15_1  15_6   15_7  37_11  \
# 0    NaN   NaN    3.0    3.0   NaN    NaN    NaN    NaN   3.0    1.0    NaN
# 1    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN   NaN    NaN    NaN
# 2    NaN   NaN    1.0    NaN   NaN    1.0    NaN    1.0   NaN    NaN    NaN
# 3    NaN   NaN    1.0    1.0   1.0    NaN    NaN    NaN   NaN    NaN    NaN
# 4    3.0   NaN    3.0    1.0   NaN    NaN    NaN    2.0   NaN    3.0    3.0
# 5   13.0   NaN    4.0   11.0   3.0    5.0    2.0    7.0   4.0    7.0    6.0
# 6    2.0   NaN    NaN    NaN   NaN    2.0    NaN    1.0   NaN    NaN    2.0
# 7  908.0   NaN  587.0  236.0  21.0  119.0    NaN  262.0  22.0  245.0    1.0
# 8   92.0   NaN   23.0   14.0   3.0    NaN    NaN    9.0   NaN   13.0    NaN
# 9   59.0   NaN   68.0   38.0   1.0   11.0    NaN   40.0   5.0   31.0    NaN
#
#    37_9  37_4   36_5  36_11   36_4
# 0   NaN   NaN    NaN    NaN    NaN
# 1   NaN   NaN    NaN    NaN    NaN
# 2   NaN   NaN    1.0    NaN    NaN
# 3   NaN   1.0    2.0    NaN    NaN
# 4   1.0   NaN    4.0    1.0   12.0
# 5   4.0   1.0    8.0   13.0   40.0
# 6   NaN   NaN    2.0    NaN    4.0
# 7   5.0   NaN  282.0  108.0  983.0
# 8   NaN   NaN   25.0    6.0  101.0
# 9   1.0   1.0   21.0    5.0   76.0

# %% [markdown]
# ### Replace all instances of NaN with 0

# %%
reads_df = reads_df.fillna(0)

# %% [markdown]
# ### Save as csv

# %%
reads_df.to_csv("Noro_timeseries_16S_all.csv", index=None)
