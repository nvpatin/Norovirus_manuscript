# %% [markdown]
# ## This script tests for significantly different relative abundances of genes (KOs) or gene categories between two groups using metagenome read counts, normalized by metagenome Genome Equivalent value and mapped to each gene. A t-test is used to test for significant difference, p-values corrected for multiple testing, and genes with a corrected p-value below a certain threshold are displayed in a heat map.

# %%
import os as os
import numpy as np
import pandas as pd
from statsmodels.stats.weightstats import ttest_ind
from statsmodels.stats.multitest import fdrcorrection

# %% [markdown]
# ## Import file of KOs, associated categories, and normalized read counts

# %%
os.chdir('/Users/npatin3/Desktop/GTPostdoc/Noro_Assemblies/Asymp_vs_symp')
path = "Asymp_vs_symp_KOs_readcounts.csv"

# %%
kos = pd.read_csv(path, header=0, sep=',')
kos.head()
# Out:
#         Group                 Subgroup  \
# 0  Metabolism  Carbohydrate metabolism
# 1  Metabolism  Carbohydrate metabolism
# 2  Metabolism  Carbohydrate metabolism
# 3  Metabolism  Carbohydrate metabolism
# 4  Metabolism  Carbohydrate metabolism
#
#                                            Subgroup2      KO  \
# 0        Glycolysis / Gluconeogenesis [PATH:ko00010]  K00844
# 1     Fructose and mannose metabolism [PATH:ko00051]  K00844
# 2                Galactose metabolism [PATH:ko00052]  K00844
# 3       Starch and sucrose metabolism [PATH:ko00500]  K00844
# 4  Amino sugar and nucleotide sugar metabolism [P...  K00844
#
#                        Function  ReadCounts Sample   GE  ReadCounts_Norm  \
# 0   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 1   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 2   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 3   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 4   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
#
#         dataset
# 0  Asymptomatic
# 1  Asymptomatic
# 2  Asymptomatic
# 3  Asymptomatic
# 4  Asymptomatic

# %%
# Split out the "PATH" part of Subgroup2 label
kos[['Subgroup2', 'PATH']] = kos['Subgroup2'].str.split("[", n=1, expand=True)
kos = kos.drop('PATH', axis=1)
kos.head()
# Out:
#         Group                 Subgroup  \
# 0  Metabolism  Carbohydrate metabolism
# 1  Metabolism  Carbohydrate metabolism
# 2  Metabolism  Carbohydrate metabolism
# 3  Metabolism  Carbohydrate metabolism
# 4  Metabolism  Carbohydrate metabolism
#
#                                       Subgroup2      KO  \
# 0                 Glycolysis / Gluconeogenesis   K00844
# 1              Fructose and mannose metabolism   K00844
# 2                         Galactose metabolism   K00844
# 3                Starch and sucrose metabolism   K00844
# 4  Amino sugar and nucleotide sugar metabolism   K00844
#
#                        Function  ReadCounts Sample   GE  ReadCounts_Norm  \
# 0   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 1   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 2   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 3   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 4   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
#
#         dataset
# 0  Asymptomatic
# 1  Asymptomatic
# 2  Asymptomatic
# 3  Asymptomatic
# 4  Asymptomatic

# %%
# Exclude irrelevant categories
kos2 = kos.loc[(kos['Group'] != 'Human Diseases') & 
               (kos['Group'] != 'Brite Hierarchies') & 
               (kos['Group'] != 'Organismal Systems') &
               (kos['Subgroup'] != 'Cellular community - eukaryotes')]

# %%
kos.size
# Out:
# 235930

# %%
kos2.size
# Out:
# 146530

# %% [markdown]
# ## Pull out only level of interest, ie KOs or Subgroups2

# %%
df = kos2[['KO','Sample','ReadCounts_Norm', 'dataset']]
df.head()
# Out:
#        KO Sample  ReadCounts_Norm       dataset
# 0  K00844   13_1         0.001825  Asymptomatic
# 1  K00844   13_1         0.001825  Asymptomatic
# 2  K00844   13_1         0.001825  Asymptomatic
# 3  K00844   13_1         0.001825  Asymptomatic
# 4  K00844   13_1         0.001825  Asymptomatic

# %% [markdown]
# ### For KOs only, drop duplicates within each sample

# %%
df2 = df.sort_values('ReadCounts_Norm').drop_duplicates(subset=['Sample', 'KO'], keep='last')
df2.head()
# Out:
#            KO Sample  ReadCounts_Norm       dataset
# 8696   K07720   28_1         0.001192  Asymptomatic
# 17769  K00791    4_1         0.001192   Symptomatic
# 17745  K03526   15_1         0.001192   Symptomatic
# 17742  K00919    4_1         0.001192   Symptomatic
# 17739  K00919   15_1         0.001192   Symptomatic

# %% [markdown]
# ## Run t-tests and fold-difference calculations on KOs or categories

# %% [markdown]
# #### Reformat data frame

# %%
df3 = pd.pivot_table(data=df, index='Sample', values='ReadCounts_Norm', columns='KO')
df3 = df3 = df3.reindex(['4_1','15_1','36_1','37_1','13_1','28_1','38_1','41_1','49_1']).fillna(0)
df3.head()
# Out:
# KO        K00003    K00005    K00008    K00009    K00010    K00012    K00013  \
# Sample
# 4_1     0.000000  0.000000  0.000000  0.000000  0.000000  0.005282  0.003650
# 15_1    0.004390  0.000000  0.003333  0.004386  0.013928  0.007542  0.002193
# 36_1    0.007980  0.000000  0.000000  0.000000  0.000000  0.007163  0.003082
# 37_1    0.009613  0.001641  0.000000  0.000000  0.000000  0.005042  0.003576
# 13_1    0.001825  0.000000  0.000000  0.000000  0.005474  0.018248  0.000000
#
# KO        K00014    K00016    K00018  ...  K23259    K23351    K23352  \
# Sample                                ...
# 4_1     0.014577  0.000000  0.002373  ...     0.0  0.001641  0.000000
# 15_1    0.003082  0.013277  0.005017  ...     0.0  0.001641  0.003283
# 36_1    0.002384  0.013277  0.005499  ...     0.0  0.003040  0.000000
# 37_1    0.003650  0.000000  0.002855  ...     0.0  0.003224  0.000000
# 13_1    0.007299  0.000000  0.003650  ...     0.0  0.003650  0.003650
#
# KO        K23393    K23508    K23514    K23518    K23536    K23537    K23573
# Sample
# 4_1     0.005831  0.000000  0.000000  0.001192  0.000000  0.004622  0.000000
# 15_1    0.009124  0.003082  0.000000  0.004386  0.000000  0.003576  0.003082
# 36_1    0.000000  0.000000  0.000000  0.001458  0.001825  0.000000  0.004768
# 37_1    0.000000  0.001192  0.000000  0.004386  0.001541  0.001825  0.004768
# 13_1    0.001825  0.000000  0.001825  0.001825  0.000000  0.001825  0.000000
#
# [5 rows x 1963 columns]

# %% [markdown]
# ### T-test on each gene between asymptomatic and symptomatic groups

# %% [markdown]
# #### Add new empty rows for statistical results

# %%
df4 = df3.append(pd.Series(name='ttest', dtype='int'))
df4 = df4.append(pd.Series(name='p-value', dtype='int'))
df4 = df4.append(pd.Series(name='corrected_p-value', dtype='int'))
df4 = df4.append(pd.Series(name='fold difference', dtype='int'))
df4
# Out:
# KO                   K00003    K00005    K00008    K00009    K00010    K00012  \
# Sample
# 4_1                0.000000  0.000000  0.000000  0.000000  0.000000  0.005282
# 15_1               0.004390  0.000000  0.003333  0.004386  0.013928  0.007542
# 36_1               0.007980  0.000000  0.000000  0.000000  0.000000  0.007163
# 37_1               0.009613  0.001641  0.000000  0.000000  0.000000  0.005042
# 13_1               0.001825  0.000000  0.000000  0.000000  0.005474  0.018248
# 28_1               0.000000  0.001192  0.000000  0.002384  0.000000  0.000000
# 38_1               0.004386  0.006579  0.000000  0.000000  0.000000  0.017544
# 41_1               0.004373  0.000000  0.000000  0.001458  0.001458  0.013120
# 49_1               0.003082  0.000000  0.000000  0.000000  0.000000  0.009245
# ttest                   NaN       NaN       NaN       NaN       NaN       NaN
# p-value                 NaN       NaN       NaN       NaN       NaN       NaN
# corrected_p-value       NaN       NaN       NaN       NaN       NaN       NaN
# fold difference         NaN       NaN       NaN       NaN       NaN       NaN
#
# KO                   K00013    K00014    K00016    K00018  ...    K23259  \
# Sample                                                     ...
# 4_1                0.003650  0.014577  0.000000  0.002373  ...  0.000000
# 15_1               0.002193  0.003082  0.013277  0.005017  ...  0.000000
# 36_1               0.003082  0.002384  0.013277  0.005499  ...  0.000000
# 37_1               0.003576  0.003650  0.000000  0.002855  ...  0.000000
# 13_1               0.000000  0.007299  0.000000  0.003650  ...  0.000000
# 28_1               0.009535  0.000000  0.000000  0.000000  ...  0.001192
# 38_1               0.004386  0.000000  0.000000  0.004386  ...  0.000000
# 41_1               0.017493  0.011662  0.000000  0.002915  ...  0.000000
# 49_1               0.004622  0.004622  0.001541  0.010786  ...  0.000000
# ttest                   NaN       NaN       NaN       NaN  ...       NaN
# p-value                 NaN       NaN       NaN       NaN  ...       NaN
# corrected_p-value       NaN       NaN       NaN       NaN  ...       NaN
# fold difference         NaN       NaN       NaN       NaN  ...       NaN
#
# KO                   K23351    K23352    K23393    K23508    K23514    K23518  \
# Sample
# 4_1                0.001641  0.000000  0.005831  0.000000  0.000000  0.001192
# 15_1               0.001641  0.003283  0.009124  0.003082  0.000000  0.004386
# 36_1               0.003040  0.000000  0.000000  0.000000  0.000000  0.001458
# 37_1               0.003224  0.000000  0.000000  0.001192  0.000000  0.004386
# 13_1               0.003650  0.003650  0.001825  0.000000  0.001825  0.001825
# 28_1               0.000000  0.000000  0.000000  0.000000  0.001192  0.000000
# 38_1               0.002193  0.000000  0.000000  0.000000  0.000000  0.002193
# 41_1               0.001458  0.001458  0.000000  0.001458  0.002915  0.008746
# 49_1               0.006163  0.000000  0.000000  0.000000  0.006163  0.001541
# ttest                   NaN       NaN       NaN       NaN       NaN       NaN
# p-value                 NaN       NaN       NaN       NaN       NaN       NaN
# corrected_p-value       NaN       NaN       NaN       NaN       NaN       NaN
# fold difference         NaN       NaN       NaN       NaN       NaN       NaN
#
# KO                   K23536    K23537    K23573
# Sample
# 4_1                0.000000  0.004622  0.000000
# 15_1               0.000000  0.003576  0.003082
# 36_1               0.001825  0.000000  0.004768
# 37_1               0.001541  0.001825  0.004768
# 13_1               0.000000  0.001825  0.000000
# 28_1               0.000000  0.000000  0.002384
# 38_1               0.000000  0.000000  0.004386
# 41_1               0.000000  0.001458  0.002915
# 49_1               0.000000  0.000000  0.000000
# ttest                   NaN       NaN       NaN
# p-value                 NaN       NaN       NaN
# corrected_p-value       NaN       NaN       NaN
# fold difference         NaN       NaN       NaN
#
# [13 rows x 1963 columns]

# %% [markdown]
# #### Fill new rows with results of scipy stats ttest and statsmodels Benjamini/Hochberg multitest correction

# %%
df4.iloc[9] = ttest_ind(df4.iloc[:4, :], df4.iloc[4:9, :], value=0)[0]
df4.iloc[10] = ttest_ind(df4.iloc[:4, :], df4.iloc[4:9, :], value=0)[1]
df4.iloc[11] = fdrcorrection(df4.iloc[10], alpha=0.1, method='indep')[1]
df4
# Out:
# KO                   K00003    K00005    K00008    K00009    K00010    K00012  \
# Sample
# 4_1                0.000000  0.000000  0.000000  0.000000  0.000000  0.005282
# 15_1               0.004390  0.000000  0.003333  0.004386  0.013928  0.007542
# 36_1               0.007980  0.000000  0.000000  0.000000  0.000000  0.007163
# 37_1               0.009613  0.001641  0.000000  0.000000  0.000000  0.005042
# 13_1               0.001825  0.000000  0.000000  0.000000  0.005474  0.018248
# 28_1               0.000000  0.001192  0.000000  0.002384  0.000000  0.000000
# 38_1               0.004386  0.006579  0.000000  0.000000  0.000000  0.017544
# 41_1               0.004373  0.000000  0.000000  0.001458  0.001458  0.013120
# 49_1               0.003082  0.000000  0.000000  0.000000  0.000000  0.009245
# ttest              1.317647 -0.766450  1.138550  0.294763  0.637718 -1.407341
# p-value            0.229107  0.468463  0.292352  0.776725  0.543945  0.202145
# corrected_p-value  0.522666  0.620090  0.522666  0.857798  0.682278  0.522666
# fold difference         NaN       NaN       NaN       NaN       NaN       NaN
#
# KO                   K00013    K00014    K00016    K00018  ...    K23259  \
# Sample                                                     ...
# 4_1                0.003650  0.014577  0.000000  0.002373  ...  0.000000
# 15_1               0.002193  0.003082  0.013277  0.005017  ...  0.000000
# 36_1               0.003082  0.002384  0.013277  0.005499  ...  0.000000
# 37_1               0.003576  0.003650  0.000000  0.002855  ...  0.000000
# 13_1               0.000000  0.007299  0.000000  0.003650  ...  0.000000
# 28_1               0.009535  0.000000  0.000000  0.000000  ...  0.001192
# 38_1               0.004386  0.000000  0.000000  0.004386  ...  0.000000
# 41_1               0.017493  0.011662  0.000000  0.002915  ...  0.000000
# 49_1               0.004622  0.004622  0.001541  0.010786  ...  0.000000
# ttest             -1.202940  0.336381  1.870436 -0.193881  ... -0.881917
# p-value            0.268102  0.746442  0.103612  0.851775  ...  0.407084
# corrected_p-value  0.522666  0.832116  0.465422  0.911687  ...  0.565939
# fold difference         NaN       NaN       NaN       NaN  ...       NaN
#
# KO                   K23351    K23352    K23393    K23508    K23514    K23518  \
# Sample
# 4_1                0.001641  0.000000  0.005831  0.000000  0.000000  0.001192
# 15_1               0.001641  0.003283  0.009124  0.003082  0.000000  0.004386
# 36_1               0.003040  0.000000  0.000000  0.000000  0.000000  0.001458
# 37_1               0.003224  0.000000  0.000000  0.001192  0.000000  0.004386
# 13_1               0.003650  0.003650  0.001825  0.000000  0.001825  0.001825
# 28_1               0.000000  0.000000  0.000000  0.000000  0.001192  0.000000
# 38_1               0.002193  0.000000  0.000000  0.000000  0.000000  0.002193
# 41_1               0.001458  0.001458  0.000000  0.001458  0.002915  0.008746
# 49_1               0.006163  0.000000  0.000000  0.000000  0.006163  0.001541
# ttest             -0.245331 -0.185119  1.663305  1.079794 -2.035230 -0.002970
# p-value            0.813238  0.858385  0.140201  0.316028  0.081283  0.997713
# corrected_p-value  0.884424  0.915152  0.509747  0.546166  0.447623  0.998599
# fold difference         NaN       NaN       NaN       NaN       NaN       NaN
#
# KO                   K23536    K23537    K23573
# Sample
# 4_1                0.000000  0.004622  0.000000
# 15_1               0.000000  0.003576  0.003082
# 36_1               0.001825  0.000000  0.004768
# 37_1               0.001541  0.001825  0.004768
# 13_1               0.000000  0.001825  0.000000
# 28_1               0.000000  0.000000  0.002384
# 38_1               0.000000  0.000000  0.004386
# 41_1               0.000000  0.001458  0.002915
# 49_1               0.000000  0.000000  0.000000
# ttest              1.958135  1.842609  0.879121
# p-value            0.091070  0.107931  0.408498
# corrected_p-value  0.451651  0.468736  0.567102
# fold difference         NaN       NaN       NaN
#
# [13 rows x 1963 columns]

# %% [markdown]
# ### Function to calculate fold difference between asymptomatic and symptomatic samples

# %%
def fold_difference(df, num_symp_rows, num_sample_rows):
    set1 = df.iloc[0:num_symp_rows]
    set2 = df.iloc[num_symp_rows:num_sample_rows]
    mean_diff = np.mean(set1) / np.mean(set2)
    #print(mean_diff)
    return(mean_diff)

# %% [markdown]
# ### Apply function to data frame to calculate fold difference of each column

# %%
df4 = df4.replace(0, 0.000000001)
df4.loc['fold difference'] = fold_difference(df4, 4, 9)
df4
# Out:
# KO                       K00003        K00005        K00008        K00009  \
# Sample
# 4_1                1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# 15_1               4.390448e-03  1.000000e-09  3.333174e-03  4.385965e-03
# 49_1               1.540832e-03  1.540832e-03  4.622496e-03   0.007704
# ttest              8.305805e+00  6.482319e+00  6.380053e+00  10.759070
# p-value            7.167926e-05  3.397415e-04  3.743268e-04   0.000013
# corrected_p-value  1.172553e-02  3.175774e-02  3.340016e-02   0.005175
# fold difference    1.720796e+01  1.102106e+01  1.572850e+01  38.972134
#
# KO                    K07133        K11358        K15771        K20487
# Sample
# 4_1                 0.001541  1.219307e-02  1.232666e-02  1.341663e-02
# 15_1                0.011662  8.371449e-03  1.642336e-02  2.206008e-02
# 36_1                0.003082  7.835480e-03  2.623907e-02  1.933085e-02
# 37_1                0.007299  9.208409e-03  1.315789e-02  1.472745e-02
# 13_1                0.047445  1.000000e-09  1.000000e-09  1.000000e-09
# 28_1                0.053635  1.000000e-09  1.000000e-09  1.000000e-09
# 38_1                0.054825  1.000000e-09  1.000000e-09  4.385965e-03
# 41_1                0.055394  1.000000e-09  1.000000e-09  1.457726e-03
# 49_1                0.064715  1.540832e-03  1.000000e-09  1.000000e-09
# ttest             -13.250380  9.856055e+00  6.076241e+00  8.058254e+00
# p-value             0.000003  2.353816e-05  5.027318e-04  8.702031e-05
# corrected_p-value   0.005175  7.469249e-03  3.947450e-02  1.314007e-02
# fold difference     0.106804  3.050974e+01  1.703674e+07  1.487394e+01
#
# [13 rows x 26 columns]

# %%
kos_significant.to_csv("sig_diff_KOs_CORRECTED.csv")

# %% [markdown]
# ### Make list of significant KOs

# %%
ko_list = list(kos_significant)

# %%
ko_list
# Out:
# ['K00761',
#  'K00806',
#  'K00925',
#  'K00975',
#  'K01223',
#  'K01480',
#  'K01652',
#  'K01676',
#  'K01738',
#  'K01803',
#  'K01915',
#  'K01995',
#  'K01998',
#  'K02031',
#  'K02038',
#  'K02871',
#  'K03654',
#  'K03787',
#  'K04487',
#  'K04517',
#  'K04720',
#  'K06400',
#  'K07133',
#  'K11358',
#  'K15771',
#  'K20487']

# %% [markdown]
# ### Extract rows from original data frame containing any of the significant KOs

# %%
mask = kos2['KO'].apply(lambda x: any(item for item in ko_list if item in x))
df = kos2[mask]

# %%
df.shape
# Out:
# (463, 10)

# %%
df.sort_values(by=['KO'])
# Out:
#                                       Group  \
# 15714                            Metabolism
# 15712                            Metabolism
# 15713                            Metabolism
# 15715                            Metabolism
# 5943                             Metabolism
# ...                                     ...
# 20087  Environmental Information Processing
# 20086  Environmental Information Processing
# 20085  Environmental Information Processing
# 8590                     Cellular Processes
# 20088  Environmental Information Processing
#
#                                        Subgroup  \
# 15714                     Nucleotide metabolism
# 15712                     Nucleotide metabolism
# 15713                     Nucleotide metabolism
# 15715                     Nucleotide metabolism
# 5943   Metabolism of terpenoids and polyketides
# ...                                         ...
# 20087                       Signal transduction
# 20086                       Signal transduction
# 20085                       Signal transduction
# 8590           Cellular community - prokaryotes
# 20088                       Signal transduction
#
#                               Subgroup2      KO  \
# 15714            Pyrimidine metabolism   K00761
# 15712            Pyrimidine metabolism   K00761
# 15713            Pyrimidine metabolism   K00761
# 15715            Pyrimidine metabolism   K00761
# 5943   Terpenoid backbone biosynthesis   K00806
# ...                                 ...     ...
# 20087             Two-component system   K20487
# 20086             Two-component system   K20487
# 20085             Two-component system   K20487
# 8590                    Quorum sensing   K20487
# 20088             Two-component system   K20487
#
#                                                 Function  ReadCounts Sample  \
# 15714   upp, UPRT; uracil phosphoribosyltransferase [...           1   37_1
# 15712   upp, UPRT; uracil phosphoribosyltransferase [...           2   15_1
# 15713   upp, UPRT; uracil phosphoribosyltransferase [...           1   36_1
# 15715   upp, UPRT; uracil phosphoribosyltransferase [...           1    4_1
# 5943    uppS; undecaprenyl diphosphate synthase [EC:2...           2   28_1
# ...                                                  ...         ...    ...
# 20087   nisK, spaK; two-component system, OmpR family...           1   37_1
# 20086   nisK, spaK; two-component system, OmpR family...           3   36_1
# 20085   nisK, spaK; two-component system, OmpR family...           2   15_1
# 8590    nisK, spaK; two-component system, OmpR family...           1   41_1
# 20088   nisK, spaK; two-component system, OmpR family...           2    4_1
#
#         GE  ReadCounts_Norm       dataset
# 15714  554         0.007704   Symptomatic
# 15712  984         0.014577   Symptomatic
# 15713  738         0.015351   Symptomatic
# 15715  752         0.007289   Symptomatic
# 5943   839         0.002384  Asymptomatic
# ...    ...              ...           ...
# 20087  554         0.018490   Symptomatic
# 20086  738         0.010965   Symptomatic
# 20085  984         0.027697   Symptomatic
# 8590   686         0.001458  Asymptomatic
# 20088  752         0.008343   Symptomatic
#
# [463 rows x 10 columns]

# %%
df3 = df.drop_duplicates(subset=['KO'])[['KO','Function']]
df3.head()
# Out:
#           KO                                           Function
# 246   K01803   TPI, tpiA; triosephosphate isomerase (TIM) [E...
# 724   K01223   E3.2.1.86B, bglA; 6-phospho-beta-glucosidase ...
# 867   K01676   E4.2.1.2A, fumA, fumB; fumarate hydratase, cl...
# 1471  K00975   glgC; glucose-1-phosphate adenylyltransferase...
# 1849  K00925                  ackA; acetate kinase [EC:2.7.2.1]

# %%
df3.shape
# Out:
# (26, 2)

# %%
df2.to_csv("KOs_significantly_different_all_CORRECTED.csv")

# %%
df3.to_csv("KOs_SD_CORRECTED_functions.csv")

# %% [markdown]
# ## Heat map of just the significantly different genes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
counts = pd.read_csv(path, header=0, sep=',')
counts.head()
# Out:
#         Group                 Subgroup  \
# 0  Metabolism  Carbohydrate metabolism
# 1  Metabolism  Carbohydrate metabolism
# 2  Metabolism  Carbohydrate metabolism
# 3  Metabolism  Carbohydrate metabolism
# 4  Metabolism  Carbohydrate metabolism
#
#                                            Subgroup2      KO  \
# 0        Glycolysis / Gluconeogenesis [PATH:ko00010]  K00844
# 1     Fructose and mannose metabolism [PATH:ko00051]  K00844
# 2                Galactose metabolism [PATH:ko00052]  K00844
# 3       Starch and sucrose metabolism [PATH:ko00500]  K00844
# 4  Amino sugar and nucleotide sugar metabolism [P...  K00844
#
#                        Function  ReadCounts Sample   GE  ReadCounts_Norm  \
# 0   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 1   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 2   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 3   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
# 4   HK; hexokinase [EC:2.7.1.1]           1   13_1  548         0.001825
#
#         dataset
# 0  Asymptomatic
# 1  Asymptomatic
# 2  Asymptomatic
# 3  Asymptomatic
# 4  Asymptomatic

# %%
df = counts.sort_values('ReadCounts_Norm').drop_duplicates(subset=['Sample', 'KO'], keep='last')
df.head()
# Out:
#                                   Group  \
# 11694  Not Included in Pathway or Brite
# 1921                         Metabolism
# 1916                         Metabolism
# 11684  Not Included in Pathway or Brite
# 11672  Not Included in Pathway or Brite
#
#                                            Subgroup  \
# 11694  Unclassified: genetic information processing
# 1921                        Carbohydrate metabolism
# 1916                        Carbohydrate metabolism
# 11684  Unclassified: genetic information processing
# 11672  Unclassified: genetic information processing
#
#                                 Subgroup2      KO  \
# 11694              Replication and repair  K04096
# 1921   Pyruvate metabolism [PATH:ko00620]  K07248
# 1916   Pyruvate metabolism [PATH:ko00620]  K03778
# 11684              Replication and repair  K07459
# 11672              Replication and repair  K07454
#
#                                                 Function  ReadCounts Sample  \
# 11694                        smf; DNA processing protein           1   28_1
# 1921    aldA; lactaldehyde dehydrogenase / glycolalde...           1   28_1
# 1916         ldhA; D-lactate dehydrogenase [EC:1.1.1.28]           1   28_1
# 11684   ybjD; putative ATP-dependent endonuclease of ...           1   28_1
# 11672          K07454; putative restriction endonuclease           1   28_1
#
#         GE  ReadCounts_Norm       dataset
# 11694  839         0.001192  Asymptomatic
# 1921   839         0.001192  Asymptomatic
# 1916   839         0.001192  Asymptomatic
# 11684  839         0.001192  Asymptomatic
# 11672  839         0.001192  Asymptomatic

# %%
mask = df['KO'].apply(lambda x: any(item for item in ko_list if item in x))
#inverted_mask = mask2!=True
df2 = df[mask]

# %%
df2 = df2[['KO','Sample','ReadCounts_Norm','dataset']]
df2.head()
# Out:
#            KO Sample  ReadCounts_Norm       dataset
# 18729  K03654   15_1         0.001192   Symptomatic
# 4436   K01480   28_1         0.001192  Asymptomatic
# 8132   K01995   28_1         0.001192  Asymptomatic
# 8123   K01998   28_1         0.001192  Asymptomatic
# 724    K01223   28_1         0.001192  Asymptomatic

# %% [markdown]
# ### Format for heat map

# %%
df3 = pd.pivot_table(data=df2, index='Sample', values='ReadCounts_Norm', columns='KO')
df3 = df3.fillna(0)
df3.head()
# Out:
# KO        K00761    K00806    K00925    K00975    K01223    K01480    K01652  \
# Sample
# 13_1    0.000000  0.001825  0.010949  0.000000  0.000000  0.000000  0.001825
# 15_1    0.014577  0.027414  0.092105  0.192982  0.016687  0.002384  0.043732
# 28_1    0.000000  0.002384  0.004768  0.002384  0.001192  0.001192  0.000000
# 36_1    0.015351  0.023723  0.161808  0.173358  0.023723  0.003650  0.043732
# 37_1    0.007704  0.036443  0.161808  0.275510  0.026239  0.004373  0.041667
#
# KO        K01676    K01738    K01803  ...    K03654    K03787    K04487  \
# Sample                                ...
# 13_1    0.009124  0.003650  0.001825  ...  0.014599  0.005474  0.003650
# 15_1    0.001541  0.018248  0.012774  ...  0.001192  0.018248  0.016687
# 28_1    0.013111  0.002384  0.000000  ...  0.010727  0.003576  0.000000
# 36_1    0.001541  0.017493  0.021866  ...  0.001825  0.024781  0.027697
# 37_1    0.001541  0.024653  0.017544  ...  0.004373  0.024781  0.032895
#
# KO        K04517    K04720    K06400    K07133    K11358    K15771    K20487
# Sample
# 13_1    0.000000  0.000000  0.025547  0.047445  0.000000  0.000000  0.000000
# 15_1    0.008746  0.078717  0.507299  0.011662  0.026316  0.016423  0.027697
# 28_1    0.002384  0.002384  0.003576  0.053635  0.000000  0.000000  0.000000
# 36_1    0.019737  0.054825  0.800292  0.003082  0.026316  0.026239  0.027697
# 37_1    0.013867  0.046225  0.625000  0.007299  0.023324  0.026239  0.021866
#
# [5 rows x 26 columns]

# %%
# Log transform
df3_log = np.log(df3.replace(0, 0.0000001))
df3_log.head()
# Out:
# KO         K00761    K00806    K00925     K00975     K01223     K01480  \
# Sample
# 13_1   -16.118096 -6.306275 -4.514516 -16.118096 -16.118096 -16.118096
# 15_1    -4.228293 -3.596716 -2.384823  -1.645156  -4.093153  -6.039064
# 28_1   -16.118096 -6.039064 -5.345916  -6.039064  -6.732211  -6.732211
# 36_1    -4.176583 -3.741326 -1.821347  -1.752398  -3.741326  -5.613128
# 37_1    -4.865995 -3.312002 -1.821347  -1.289131  -3.640506  -5.432265
#
# KO         K01652    K01676    K01738     K01803  ...    K03654    K03787  \
# Sample                                            ...
# 13_1    -6.306275 -4.696837 -5.613128  -6.306275  ... -4.226834 -5.207663
# 15_1    -3.129680 -6.475433 -4.003690  -4.360365  ... -6.732211 -4.003690
# 28_1   -16.118096 -4.334315 -6.039064 -16.118096  ... -4.534986 -5.633598
# 36_1    -3.129680 -6.475433 -4.045971  -3.822827  ... -6.306275 -3.697664
# 37_1    -3.178054 -6.475433 -3.702844  -4.043051  ... -5.432265 -3.697664
#
# KO         K04487     K04517     K04720    K06400    K07133     K11358  \
# Sample
# 13_1    -5.613128 -16.118096 -16.118096 -3.667218 -3.048179 -16.118096
# 15_1    -4.093153  -4.739118  -2.541894 -0.678654 -4.451436  -3.637586
# 28_1   -16.118096  -6.039064  -6.039064 -5.633598 -2.925548 -16.118096
# 36_1    -3.586439  -3.925268  -2.903617 -0.222779 -5.782286  -3.637586
# 37_1    -3.414443  -4.278208  -3.074235 -0.470004 -4.919981  -3.758289
#
# KO         K15771     K20487
# Sample
# 13_1   -16.118096 -16.118096
# 15_1    -4.109051  -3.586439
# 28_1   -16.118096 -16.118096
# 36_1    -3.640506  -3.586439
# 37_1    -3.640506  -3.822827
#
# [5 rows x 26 columns]

# %%
# Square root transform
df3_sqrt = np.sqrt(df3.replace(0, 0.0000001))
df3_sqrt.head()
# Out:
# KO        K00761    K00806    K00925    K00975    K01223    K01480    K01652  \
# Sample
# 13_1    0.000316  0.042718  0.104637  0.000316  0.000316  0.000316  0.042718
# 15_1    0.120736  0.165570  0.303488  0.439298  0.129176  0.048824  0.209121
# 28_1    0.000316  0.048824  0.069048  0.048824  0.034524  0.034524  0.000316
# 36_1    0.123899  0.154022  0.402253  0.416362  0.154022  0.060412  0.209121
# 37_1    0.087773  0.190901  0.402253  0.524891  0.161985  0.066130  0.204124
#
# KO        K01676    K01738    K01803  ...    K03654    K03787    K04487  \
# Sample                                ...
# 13_1    0.095520  0.060412  0.042718  ...  0.120824  0.073990  0.060412
# 15_1    0.039253  0.135086  0.113021  ...  0.034524  0.135086  0.129176
# 28_1    0.114503  0.048824  0.000316  ...  0.103572  0.059797  0.000316
# 36_1    0.039253  0.132260  0.147871  ...  0.042718  0.157421  0.166424
# 37_1    0.039253  0.157014  0.132453  ...  0.066130  0.157421  0.181369
#
# KO        K04517    K04720    K06400    K07133    K11358    K15771    K20487
# Sample
# 13_1    0.000316  0.000316  0.159836  0.217819  0.000316  0.000316  0.000316
# 15_1    0.093522  0.280566  0.712249  0.107990  0.162221  0.128154  0.166424
# 28_1    0.048824  0.048824  0.059797  0.231593  0.000316  0.000316  0.000316
# 36_1    0.140488  0.234146  0.894590  0.055513  0.162221  0.161985  0.166424
# 37_1    0.117760  0.215000  0.790569  0.085436  0.152721  0.161985  0.147871
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Set palette for color bar

# %%
my_palette = dict(zip(df2.dataset.unique(), ["green","red"]))
row_colors = df.dataset.map(my_palette)
sampz = df.Sample

# %%
sample_colors = sampz.to_frame().join(row_colors)
sample_colors = sample_colors.drop_duplicates(subset=['Sample'])
sample_colors = sample_colors.set_index('Sample')
sample_colors.head()
# Out:
#        dataset
# Sample
# 28_1       red
# 15_1     green
# 37_1     green
# 4_1      green
# 36_1     green

# %% [markdown]
# ## Make the heatmap

# %%
p = sns.clustermap(df3_sqrt, cmap='YlGnBu', figsize=(20,10), xticklabels=False, method='ward', metric='euclidean', row_colors = sample_colors)

# %%
p = sns.clustermap(df3_sqrt, cmap='YlGnBu', method='ward', metric='euclidean', xticklabels=False, yticklabels=False, 
                   row_colors = sample_colors)
hm = p.ax_heatmap.get_position()
plt.setp(p.ax_heatmap.yaxis.get_majorticklabels(), fontsize=12)
plt.setp(p.ax_heatmap.xaxis.get_majorticklabels(), fontsize=18)
p.ax_heatmap.set_position([hm.x0, hm.y0, hm.width*3, hm.height])
col = p.ax_col_dendrogram.get_position()
row = p.ax_row_dendrogram.get_position()
p.ax_col_dendrogram.set_position([col.x0, col.y0, col.width*3, col.height*0.5])
p.ax_row_dendrogram.set_position([row.x0+0.07, row.y0, row.width*0.75, row.height])

# %%
p.savefig("All_SD_CORRECTED_KOs_sqrt_nolabels.png")
